# %% [markdown]
# - Decide what dataset you'll use for your final project.
# - Import the data into a Jupyter notebook using pandas.
# - Document where you got the data. Tell me about the available data, with links to any available documentation. Tell me about the scope of the data: source, time period, what the data can and can't tell you.
# - Then upload your notebook here. If you have a very large dataset, do not upload that dataset to bCourses! Just upload the notebook and share a link to the dataset with me in the Markdown.

# %% [markdown]
# # Import data

# %% [markdown]
# The data I'm using for this project is the [Street Tree List]('https://data.sfgov.org/City-Infrastructure/Street-Tree-List/tkzw-k3nq') from San Francisco Department of Public Works. I downloaded the data on Nov. 6, 2022. At the time, the data set was last updated on Nov. 6, 2022 as well.

# %% [markdown]
# `Source`: DataSF, data provided by San Francisco Department of Public Works
#
# `Data Dictionary`: See [here](https://data.sfgov.org/api/views/tkzw-k3nq/files/biK1RHNRcrlnB42VCsuvdib3tybKjazIH4kuDcrOczw?download=true&filename=DPW_DataDictionary_Street-Tree-List.pdf)
#
# `Time period`: Created in Sep. 24, 2012. Updated daily. The earlist `PlantDate` is Sep. 19, 1955.
#
# `What it can tell me`:
# - Where the street trees are located in San Francisco?
# - Which part of the city is covered by more trees?
# - What species of trees are planted in San Francisco?
# - How tall are the trees?
# - Who are the caregivers of the tree?
# - When was the tree planted? What are the years when there were more trees planted?
#
# `What it can not tell me`:
# - Demographic data about San Francisco. If I want to see which district / neighborhood has more trees, or calculate which part of the city has more trees per square mile, I still need to use census data or other data sets to compliment this.
# - For the caregiver of the trees, it only tells me if it's an agency or a person, but not the name of the person.

# %%
import pandas as pd
import altair as alt

# %%
sf_trees = pd.read_csv('Street_Tree_List.csv')

# %%
sf_trees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196590 entries, 0 to 196589
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   TreeID                     196590 non-null  int64
#  1   qLegalStatus               196533 non-null  object
#  2   qSpecies                   196590 non-null  object
#  3   qAddress                   195097 non-null  object
#  4   SiteOrder                  194796 non-null  float64
#  5   qSiteInfo                  196590 non-null  object
#  6   PlantType                  196590 non-null  object
#  7   qCaretaker                 196590 non-null  object
#  8   qCareAssistant             24707 non-null   object
#  9   PlantDate                  70878 non-null   object
#  10  DBH                        153021 non-null  float64
#  11  PlotSize                   146229 non-null  object
#  12  PermitNotes                53367 non-null   object
#  13  XCoord                     193644 non-null  float64
#  14  YCoord                     193644 non-null  float64
#  15  Latitude                   193644 non-null  float64
#  16  Longitude                  193644 non-null  float64
#  17  Location                   193644 non-null  object
#  18  Fire Prevention Districts  193393 non-null  float64
#  19  Police Districts           193446 non-null  float64
#  20  Supervisor Districts       193507 non-null  float64
#  21  Zip Codes                  193501 non-null  float64
#  22  Neighborhoods (old)        193503 non-null  float64
# dtypes: float64(11), int64(1), object(11)
# memory usage: 34.5+ MB

# %%
# convert the `PlantDate` Dtype to datetime

sf_trees['PlantDate'] = pd.to_datetime(sf_trees['PlantDate'])

# %%
sf_trees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196590 entries, 0 to 196589
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   TreeID                     196590 non-null  int64
#  1   qLegalStatus               196533 non-null  object
#  2   qSpecies                   196590 non-null  object
#  3   qAddress                   195097 non-null  object
#  4   SiteOrder                  194796 non-null  float64
#  5   qSiteInfo                  196590 non-null  object
#  6   PlantType                  196590 non-null  object
#  7   qCaretaker                 196590 non-null  object
#  8   qCareAssistant             24707 non-null   object
#  9   PlantDate                  70878 non-null   datetime64[ns]
#  10  DBH                        153021 non-null  float64
#  11  PlotSize                   146229 non-null  object
#  12  PermitNotes                53367 non-null   object
#  13  XCoord                     193644 non-null  float64
#  14  YCoord                     193644 non-null  float64
#  15  Latitude                   193644 non-null  float64
#  16  Longitude                  193644 non-null  float64
#  17  Location                   193644 non-null  object
#  18  Fire Prevention Districts  193393 non-null  float64
#  19  Police Districts           193446 non-null  float64
#  20  Supervisor Districts       193507 non-null  float64
#  21  Zip Codes                  193501 non-null  float64
#  22  Neighborhoods (old)        193503 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(1), object(10)
# memory usage: 34.5+ MB

# %%
sf_trees
# Out:
#         TreeID      qLegalStatus  \
# 0       217365   Section 806 (d)
# 1        92771    DPW Maintained
# 2        23904    DPW Maintained
# 3        28646    DPW Maintained
# 4       229807    DPW Maintained
# ...        ...               ...
# 196585  231304    Permitted Site
# 196586  269391    Permitted Site
# 196587  267351  Significant Tree
# 196588  160078    DPW Maintained
# 196589  269393   Section 806 (d)
#
#                                                  qSpecies  \
# 0       Ceanothus 'Ray Hartman' :: California Lilac 'R...
# 1                   Tristaniopsis laurina :: Swamp Myrtle
# 2          Prunus subhirtella 'Pendula' :: Weeping Cherry
# 3          Prunus subhirtella 'Pendula' :: Weeping Cherry
# 4                      Jacaranda mimosifolia :: Jacaranda
# ...                                                   ...
# 196585      Metrosideros excelsa :: New Zealand Xmas Tree
# 196586  Ceanothus 'Ray Hartman' :: California Lilac 'R...
# 196587          Magnolia grandiflora :: Southern Magnolia
# 196588                 Jacaranda mimosifolia :: Jacaranda
# 196589                                            :: Tree
#
#                    qAddress  SiteOrder                         qSiteInfo  \
# 0           707 Rockdale Dr        1.0    Sidewalk: Property side : Yard
# 1           11X Blanken Ave        4.0      Sidewalk: Curb side : Cutout
# 2          1600X Webster St        6.0                   Median : Cutout
# 3          1600X Webster St        7.0                   Median : Cutout
# 4            2560 Bryant St        1.0      Sidewalk: Curb side : Cutout
# ...                     ...        ...                               ...
# 196585        365 Valley St        1.0      Sidewalk: Curb side : Cutout
# 196586        134 Aptos Ave        2.0    Sidewalk: Property side : Yard
# 196587  295 Yerba Buena Ave        1.0    Sidewalk: Property side : Yard
# 196588       420 Otsego Ave        1.0      Sidewalk: Curb side : Cutout
# 196589      2724 Pacheco St        1.0  Sidewalk: Property side : Cutout
#
#        PlantType qCaretaker qCareAssistant  PlantDate  ...        XCoord  \
# 0           Tree    Private            NaN 2021-10-14  ...  5.997488e+06
# 1           Tree    Private            NaN 2021-10-14  ...  6.011718e+06
# 2           Tree        DPW            NaN        NaT  ...  6.003596e+06
# 3           Tree        DPW            NaN        NaT  ...  6.003558e+06
# 4           Tree    Private            NaN        NaT  ...  6.009700e+06
# ...          ...        ...            ...        ...  ...           ...
# 196585      Tree    Private            NaN 1987-12-05  ...  6.003550e+06
# 196586      Tree    Private            NaN 2022-11-02  ...  5.992950e+06
# 196587      Tree    Private            NaN 2022-11-03  ...  5.995171e+06
# 196588      Tree    Private            NaN 2022-11-12  ...  6.000125e+06
# 196589      Tree    Private            NaN        NaT  ...  5.986552e+06
#
#               YCoord   Latitude   Longitude  \
# 0       2.098235e+06  37.741209 -122.451285
# 1       2.087394e+06  37.712247 -122.401320
# 2       2.114195e+06  37.785380 -122.431304
# 3       2.114375e+06  37.785872 -122.431449
# 4       2.102427e+06  37.753411 -122.409355
# ...              ...        ...         ...
# 196585  2.099202e+06  37.744210 -122.430394
# 196586  2.094085e+06  37.729555 -122.466675
# 196587  2.095630e+06  37.733924 -122.459107
# 196588  2.091352e+06  37.722460 -122.441674
# 196589  2.101661e+06  37.749985 -122.489349
#
#                                          Location  Fire Prevention Districts  \
# 0        (37.74120925101712, -122.45128526411095)                        9.0
# 1       (37.712246915438215, -122.40132023435935)                       10.0
# 2        (37.78537959802679, -122.43130418097743)                       13.0
# 3        (37.78587163716589, -122.43144931782685)                       13.0
# 4        (37.75341142310638, -122.40935530851043)                        2.0
# ...                                           ...                        ...
# 196585   (37.74420986420245, -122.43039418027085)                        2.0
# 196586     (37.7295545299999, -122.4666745393668)                        9.0
# 196587   (37.73392381107357, -122.45910719357623)                        9.0
# 196588   (37.72245966606217, -122.44167446391262)                        9.0
# 196589  (37.749985284338045, -122.48934928500269)                        1.0
#
#         Police Districts Supervisor Districts  Zip Codes  Neighborhoods (old)
# 0                    7.0                  4.0       59.0                 40.0
# 1                    3.0                  8.0      309.0                  1.0
# 2                    9.0                 11.0    29490.0                 13.0
# 3                    9.0                 11.0    29490.0                 13.0
# 4                    4.0                  7.0    28859.0                 19.0
# ...                  ...                  ...        ...                  ...
# 196585               7.0                  5.0       63.0                 22.0
# 196586               8.0                  4.0       59.0                 40.0
# 196587               7.0                  4.0       59.0                 40.0
# 196588               7.0                  6.0    28861.0                 25.0
# 196589               8.0                  3.0    29491.0                 35.0
#
# [196590 rows x 23 columns]
